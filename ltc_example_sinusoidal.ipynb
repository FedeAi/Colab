# %% [markdown]
# <a href="https://colab.research.google.com/github/FedeAi/Colab/blob/main/ltc_example_sinusoidal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The basics of Neural Circuit Policies
#
# In this tutorial we will build three recurrent neural networks based on the LTC model:
#
# *   A fully-connected network
# *   A sparse, randomly wired network
# *   A sparse, structured network based on the NCP principles
#
# ![wirings.png](https://raw.githubusercontent.com/mlech26l/keras-ncp/master/misc/wirings.png)
#
# We will train these networks on some generated time-series and compare their training performance.

# %%
# Install dependencies if they are not installed yet
# !pip install -U tensorflow seaborn keras-ncp
# Out:
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.10.1)
# Collecting keras-ncp
#   Downloading https://files.pythonhosted.org/packages/ff/7a/ba70681b26407682c94c863b64e56600443bb356a7ef74555bda026f3afb/keras_ncp-1.0rc6-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.10.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied, skipping upgrade: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.9.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.31.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.5)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.2 in /usr/local/lib/python3.6/dist-packages (from seaborn) (3.2.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.22.0 in /usr/local/lib/python3.6/dist-packages (from seaborn) (1.0.5)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from keras-ncp) (20.4)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from keras-ncp) (0.16.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (49.2.0)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.17.2)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.23.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.2.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.2->seaborn) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.2->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.22.0->seaborn) (2018.9)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Installing collected packages: keras-ncp
#   Found existing installation: keras-ncp 1.0rc5
#     Uninstalling keras-ncp-1.0rc5:
#       Successfully uninstalled keras-ncp-1.0rc5
# Successfully installed keras-ncp-1.0rc6

# %%
import numpy as np
import os
from tensorflow import keras
import kerasncp as kncp
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Generating synthetic sinusoidal training data

# %%
N = 48 # Length of the time-series
# Input feature is a sine and a cosine wave
data_x = np.stack(
    [np.sin(np.linspace(0, 3 * np.pi, N)), np.cos(np.linspace(0, 3 * np.pi, N))], axis=1
)
data_x = np.expand_dims(data_x, axis=0).astype(np.float32)  # Add batch dimension
# Target output is a sine with double the frequency of the input signal
data_y = np.sin(np.linspace(0, 6 * np.pi, N)).reshape([1, N, 1]).astype(np.float32)
print("data_x.shape: ", str(data_x.shape))
print("data_y.shape: ", str(data_y.shape))

# Let's visualize the training data
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(data_x[0, :, 0], label="Input feature 1")
plt.plot(data_x[0, :, 1], label="Input feature 1")
plt.plot(data_y[0, :, 0], label="Target output")
plt.ylim((-1, 1))
plt.title("Training data")
plt.legend(loc="upper right")
plt.show()
# Out:
# data_x.shape:  (1, 48, 2)
# data_y.shape:  (1, 48, 1)

# %% [markdown]
# ## The LTC model
#
# The ```keras-ncp``` package is composed of two main parts:
#
# - The LTC model as a ```tf.keras.layers.Layer``` RNN cell.
# - An wiring architecture for the LTC cell above
#
# The wiring could be fully-connected (all-to-all) or sparsely designed using the NCP principles introduced in the paper.
#
# Note that as the LTC model is expressed in the form of a system of [ordinary differential equations in time](https://arxiv.org/abs/2006.04439), any instance of it is inherently a recurrent neural network (RNN).
# That's why this simple example considers a sinusoidal time-series.

# %% [markdown]
# ### Our first LTC model with fully-connected wiring

# %%
fc_wiring = kncp.wirings.FullyConnected(8, 1)  # 8 units, 1 of which is a motor neuron
ltc_cell = kncp.LTCCell(fc_wiring)

model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        keras.layers.RNN(ltc_cell, return_sequences=True),
    ]
)
model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, None, 1)           350
# =================================================================
# Total params: 350
# Trainable params: 350
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Draw the wiring diagram of the network

# %%
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = ltc_cell.draw_graph(draw_labels=True)
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualizing the prediction of the network before training

# %%
# Let's visualize how LTC initialy performs before the training
sns.set()
prediction = model(data_x).numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[0, :, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="LTC output")
plt.ylim((-1, 1))
plt.title("Before training")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Training the model

# %%
# Train the model for 400 epochs (= training steps)
hist = model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=1)
# Out:
# Epoch 1/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5127
# Epoch 2/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4808
# Epoch 3/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4685
# Epoch 4/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4720
# Epoch 5/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4735
# Epoch 6/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4683
# Epoch 7/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4611
# Epoch 8/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4545
# Epoch 9/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4497
# Epoch 10/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4465
# Epoch 11/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4440
# Epoch 12/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4405
# Epoch 13/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4353
# Epoch 14/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4283
# Epoch 15/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4212
# Epoch 16/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4167
# Epoch 17/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4128
# Epoch 18/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4049
# Epoch 19/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3962
# Epoch 20/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3883
# Epoch 21/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3800
# Epoch 22/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3701
# Epoch 23/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3604
# Epoch 24/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3520
# Epoch 25/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3443
# Epoch 26/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3375
# Epoch 27/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3311
# Epoch 28/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3241
# Epoch 29/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3164
# Epoch 30/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3093
# Epoch 31/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3027
# Epoch 32/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2962
# Epoch 33/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2901
# Epoch 34/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2846
# Epoch 35/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2795
# Epoch 36/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2749
# Epoch 37/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2710
# Epoch 38/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2673
# Epoch 39/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2634
# Epoch 40/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2601
# Epoch 41/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2568
# Epoch 42/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2538
# Epoch 43/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2504
# Epoch 44/400
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2472
# Epoch 45/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2436
# Epoch 46/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2392
# Epoch 47/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2332
# Epoch 48/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2203
# Epoch 49/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2098
# Epoch 50/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2009
# Epoch 51/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1913
# Epoch 52/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1763
# Epoch 53/400
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1647
# Epoch 54/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1445
# Epoch 55/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1377
# Epoch 56/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1576
# Epoch 57/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1313
# Epoch 58/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1158
# Epoch 59/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1196
# Epoch 60/400
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0993
# Epoch 61/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0995
# Epoch 62/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 63/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0898
# Epoch 64/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0803
# Epoch 65/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0726
# Epoch 66/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0733
# Epoch 67/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0694
# Epoch 68/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0570
# Epoch 69/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0499
# Epoch 70/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0500
# Epoch 71/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0406
# Epoch 72/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0399
# Epoch 73/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0373
# Epoch 74/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 75/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0285
# Epoch 76/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 77/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 78/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 79/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 80/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0203
# Epoch 81/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0176
# Epoch 82/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0169
# Epoch 83/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 84/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0128
# Epoch 85/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0124
# Epoch 86/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 87/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 88/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 89/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 90/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 91/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 92/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0076
# Epoch 93/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0065
# Epoch 94/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 95/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 96/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 97/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 98/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0051
# Epoch 99/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 100/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 101/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 102/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 103/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 104/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 105/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 106/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 107/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 108/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 109/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 110/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 111/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 112/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 113/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 114/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 115/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 116/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 117/400
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 118/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 119/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 120/400
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 121/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 122/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 123/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 124/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 125/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 126/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 127/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 128/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 129/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 130/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 131/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 132/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 133/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 134/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 135/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 136/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 137/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 138/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 139/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 140/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 141/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 142/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 143/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 144/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 145/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 146/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 147/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 148/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 149/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 150/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 151/400
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 152/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 153/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 154/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 155/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 156/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 157/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 158/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 159/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 160/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 161/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 162/400
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 163/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 164/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 165/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 166/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 167/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 168/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 169/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 170/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 171/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 172/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 173/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 174/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 175/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 176/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 177/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 178/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 179/400
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 180/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 181/400
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 182/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.9884e-04
# Epoch 183/400
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8592e-04
# Epoch 184/400
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7315e-04
# Epoch 185/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6095e-04
# Epoch 186/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4893e-04
# Epoch 187/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.3714e-04
# Epoch 188/400
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2551e-04
# Epoch 189/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.1406e-04
# Epoch 190/400
# 1/1 [==============================] - 0s 1ms/step - loss: 9.0276e-04
# Epoch 191/400
# 1/1 [==============================] - 0s 1ms/step - loss: 8.9163e-04
# Epoch 192/400
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8062e-04
# Epoch 193/400
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6979e-04
# Epoch 194/400
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5912e-04
# Epoch 195/400
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4860e-04
# Epoch 196/400
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3824e-04
# Epoch 197/400
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2803e-04
# Epoch 198/400
# 1/1 [==============================] - 0s 1ms/step - loss: 8.1795e-04
# Epoch 199/400
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0804e-04
# Epoch 200/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.9826e-04
# Epoch 201/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8862e-04
# Epoch 202/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.7912e-04
# Epoch 203/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6976e-04
# Epoch 204/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6053e-04
# Epoch 205/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.5143e-04
# Epoch 206/400
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4245e-04
# Epoch 207/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.3360e-04
# Epoch 208/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2487e-04
# Epoch 209/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1626e-04
# Epoch 210/400
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0776e-04
# Epoch 211/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.9939e-04
# Epoch 212/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9113e-04
# Epoch 213/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8298e-04
# Epoch 214/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7495e-04
# Epoch 215/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6702e-04
# Epoch 216/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.5921e-04
# Epoch 217/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.5150e-04
# Epoch 218/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4389e-04
# Epoch 219/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3638e-04
# Epoch 220/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2898e-04
# Epoch 221/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2167e-04
# Epoch 222/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1447e-04
# Epoch 223/400
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0736e-04
# Epoch 224/400
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0035e-04
# Epoch 225/400
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9343e-04
# Epoch 226/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8660e-04
# Epoch 227/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7987e-04
# Epoch 228/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7322e-04
# Epoch 229/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6667e-04
# Epoch 230/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6020e-04
# Epoch 231/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.5381e-04
# Epoch 232/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4752e-04
# Epoch 233/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4130e-04
# Epoch 234/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3517e-04
# Epoch 235/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2912e-04
# Epoch 236/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2315e-04
# Epoch 237/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1726e-04
# Epoch 238/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1144e-04
# Epoch 239/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0571e-04
# Epoch 240/400
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0004e-04
# Epoch 241/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9446e-04
# Epoch 242/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8894e-04
# Epoch 243/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8350e-04
# Epoch 244/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7813e-04
# Epoch 245/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7283e-04
# Epoch 246/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6760e-04
# Epoch 247/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6243e-04
# Epoch 248/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5734e-04
# Epoch 249/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5231e-04
# Epoch 250/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4734e-04
# Epoch 251/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4244e-04
# Epoch 252/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3761e-04
# Epoch 253/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3283e-04
# Epoch 254/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2812e-04
# Epoch 255/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2347e-04
# Epoch 256/400
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1888e-04
# Epoch 257/400
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1434e-04
# Epoch 258/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0987e-04
# Epoch 259/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0545e-04
# Epoch 260/400
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0109e-04
# Epoch 261/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9679e-04
# Epoch 262/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9254e-04
# Epoch 263/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8835e-04
# Epoch 264/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8421e-04
# Epoch 265/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8012e-04
# Epoch 266/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7608e-04
# Epoch 267/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7210e-04
# Epoch 268/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6816e-04
# Epoch 269/400
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6428e-04
# Epoch 270/400
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6044e-04
# Epoch 271/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5666e-04
# Epoch 272/400
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5292e-04
# Epoch 273/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4923e-04
# Epoch 274/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4558e-04
# Epoch 275/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4198e-04
# Epoch 276/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3843e-04
# Epoch 277/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3492e-04
# Epoch 278/400
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3145e-04
# Epoch 279/400
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2803e-04
# Epoch 280/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2465e-04
# Epoch 281/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2131e-04
# Epoch 282/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1802e-04
# Epoch 283/400
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1476e-04
# Epoch 284/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1155e-04
# Epoch 285/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0837e-04
# Epoch 286/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0524e-04
# Epoch 287/400
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0214e-04
# Epoch 288/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9908e-04
# Epoch 289/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9606e-04
# Epoch 290/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9307e-04
# Epoch 291/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9012e-04
# Epoch 292/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8721e-04
# Epoch 293/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8434e-04
# Epoch 294/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8149e-04
# Epoch 295/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7869e-04
# Epoch 296/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7592e-04
# Epoch 297/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7318e-04
# Epoch 298/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7047e-04
# Epoch 299/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6780e-04
# Epoch 300/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6516e-04
# Epoch 301/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6255e-04
# Epoch 302/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5997e-04
# Epoch 303/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5742e-04
# Epoch 304/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5491e-04
# Epoch 305/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5242e-04
# Epoch 306/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4996e-04
# Epoch 307/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4754e-04
# Epoch 308/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4514e-04
# Epoch 309/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4277e-04
# Epoch 310/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4042e-04
# Epoch 311/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3811e-04
# Epoch 312/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3582e-04
# Epoch 313/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3356e-04
# Epoch 314/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3133e-04
# Epoch 315/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2912e-04
# Epoch 316/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2694e-04
# Epoch 317/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2478e-04
# Epoch 318/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2265e-04
# Epoch 319/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2054e-04
# Epoch 320/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1846e-04
# Epoch 321/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1640e-04
# Epoch 322/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1437e-04
# Epoch 323/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1236e-04
# Epoch 324/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1037e-04
# Epoch 325/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0840e-04
# Epoch 326/400
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0646e-04
# Epoch 327/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0454e-04
# Epoch 328/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0264e-04
# Epoch 329/400
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0076e-04
# Epoch 330/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9891e-04
# Epoch 331/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9707e-04
# Epoch 332/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9526e-04
# Epoch 333/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9347e-04
# Epoch 334/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9169e-04
# Epoch 335/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8994e-04
# Epoch 336/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8821e-04
# Epoch 337/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8649e-04
# Epoch 338/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8480e-04
# Epoch 339/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8312e-04
# Epoch 340/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8146e-04
# Epoch 341/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7982e-04
# Epoch 342/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7820e-04
# Epoch 343/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7660e-04
# Epoch 344/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7501e-04
# Epoch 345/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7345e-04
# Epoch 346/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7190e-04
# Epoch 347/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7036e-04
# Epoch 348/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6885e-04
# Epoch 349/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6735e-04
# Epoch 350/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6586e-04
# Epoch 351/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6439e-04
# Epoch 352/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6294e-04
# Epoch 353/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6151e-04
# Epoch 354/400
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6009e-04
# Epoch 355/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5868e-04
# Epoch 356/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5729e-04
# Epoch 357/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5592e-04
# Epoch 358/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5456e-04
# Epoch 359/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5321e-04
# Epoch 360/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5188e-04
# Epoch 361/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5056e-04
# Epoch 362/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4926e-04
# Epoch 363/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4797e-04
# Epoch 364/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4669e-04
# Epoch 365/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4543e-04
# Epoch 366/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4418e-04
# Epoch 367/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4295e-04
# Epoch 368/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4173e-04
# Epoch 369/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4052e-04
# Epoch 370/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3932e-04
# Epoch 371/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3814e-04
# Epoch 372/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3696e-04
# Epoch 373/400
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3581e-04
# Epoch 374/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3466e-04
# Epoch 375/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3352e-04
# Epoch 376/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3240e-04
# Epoch 377/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3129e-04
# Epoch 378/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3019e-04
# Epoch 379/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2910e-04
# Epoch 380/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2802e-04
# Epoch 381/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2695e-04
# Epoch 382/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2590e-04
# Epoch 383/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2485e-04
# Epoch 384/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2382e-04
# Epoch 385/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2280e-04
# Epoch 386/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2179e-04
# Epoch 387/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2078e-04
# Epoch 388/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1979e-04
# Epoch 389/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1881e-04
# Epoch 390/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1784e-04
# Epoch 391/400
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1688e-04
# Epoch 392/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1593e-04
# Epoch 393/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1498e-04
# Epoch 394/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1405e-04
# Epoch 395/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1313e-04
# Epoch 396/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1221e-04
# Epoch 397/400
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1131e-04
# Epoch 398/400
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1041e-04
# Epoch 399/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0953e-04
# Epoch 400/400
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0865e-04

# %% [markdown]
# ### Plotting the training loss

# %%
# Let's visualize the training loss
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Training loss")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.show()

# %% [markdown]
# ### Plotting the prediction of the trained model

# %%
# How does the trained model now fit to the sinusoidal function?
prediction = model(data_x).numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[0, :, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="LTC output",linestyle="dashed")
plt.ylim((-1, 1))
plt.legend(loc="upper right")
plt.title("After training")
plt.show()

# %% [markdown]
# ## Other wiring architectures
#
# Next, let's see how we can define other wiring architectures and compare them to the fully-connected network above

# %% [markdown]
# ### Random network with 75% sparsity
#
# Let's create a randomly wired network where 75% of all synapses are removed.

# %%
# Define LTC cell and wiring architecture
rnd_wiring = kncp.wirings.Random(8, 1,sparsity_level=0.75)  # 8 units, 1 motor neuron
sparse_cell = kncp.LTCCell(rnd_wiring)

# Define Keras model
sparse_model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        keras.layers.RNN(sparse_cell, return_sequences=True),
    ]
)
sparse_model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

# Plot the wiring
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = sparse_cell.draw_graph(draw_labels=True)
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing random sparse vs fully-connected networks

# %%
hist_rand = sparse_model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=0)
# This may take a while (training the sprase LTC model)
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Fully-connected")
plt.plot(hist_rand.history["loss"], label="Random (75% sparsity)")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.ylabel("Training loss")
plt.show()

# %% [markdown]
# We see that the sparse model is not able to fit the sinusoidal signal as perfectly as the fully-connected architecture.
#
# ### Neural Circuit Policy wiring architecture

# %%
ncp_arch = kncp.wirings.NCP(
    inter_neurons=3,  # Number of inter neurons
    command_neurons=4,  # Number of command neurons
    motor_neurons=1,  # Number of motor neurons
    sensory_fanout=2,  # How many outgoing synapses has each sensory neuron
    inter_fanout=2,  # How many outgoing synapses has each inter neuron
    recurrent_command_synapses=3,  # Now many recurrent synapses are in the
    # command neuron layer
    motor_fanin=4,  # How many incomming syanpses has each motor neuron
)
ncp_cell = kncp.LTCCell(ncp_arch)

ncp_model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        keras.layers.RNN(ncp_cell, return_sequences=True),
    ]
)
ncp_model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = ncp_cell.draw_graph(draw_labels=True, neuron_colors={"command": "tab:cyan"})
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1.1, 1.1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %%
hist_ncp = ncp_model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=0)
# This may take a while (training the LTC model)
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Fully-connected")
plt.plot(hist_rand.history["loss"], label="Random (75% sparsity)")
plt.plot(hist_ncp.history["loss"], label="NCP")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.ylabel("Training loss")
plt.show()

# %% [markdown]
# We see that the network with the NCP wiring architecture could fit the data as close as the fully-connected model.
#
# ### Computing the sparsity of a NCP network

# %%
# Let's compare how many synapses the NCP network has compared to the fully-connected one
sparsity = 1 - ncp_cell.synapse_count /ltc_cell.synapse_count
print("Sparsity level is {:0.2f}%".format(100*sparsity))
# Out:
# Sparsity level is 79.69%

# %% [markdown]
# The network with the NCP wiring performs as good as the fully-connected network but is even sparser than our random network tested above.
